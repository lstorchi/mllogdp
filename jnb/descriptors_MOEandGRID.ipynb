# %%
import pandas as pd
file = './data/MOE_and_GRID.csv'
df = pd.read_csv(file)
merged_dataframe_MOEnostri = pd.DataFrame(df)
merged_dataframe_MOEnostri
# Out:
#       Unnamed: 0       UNIQUEID  \
# 0              0  A-logD7.4-100
# 1              1  A-logD7.4-101
# 2              2  A-logD7.4-104
# 3              3  A-logD7.4-105
# 4              4  A-logD7.4-106
# ...          ...            ...
# 1086        1086           O-88
# 1087        1087            O-9
# 1088        1088           O-94
# 1089        1089           O-97
# 1090        1090           O-98
#
#                                                   SMILE  SETID  \
# 0          Fc1cc2c(N(C=C(C(O)=O)C2=O)C2CC2)cc1N1CCNCC1     Tr
# 1          S1(=O)(=O)N(CCN1C)c1cc2c([nH]cc2CCN(C)C)cc1     Tr
# 2                              OC=1C(=O)C=CN(CCCO)C=1C     Tr
# 3      Fc1cc2c(N(C=C(C(O)=O)C2=O)c2ccccc2C)cc1N1CCNCC1     Tr
# 4                        OC=1C(=O)C=CN(CCC(=O)NCC)C=1C     Tr
# ...                                                 ...    ...
# 1086                       O(CC(O)CNC(C)C)c1ccccc1CC=C     Tr
# 1087   O1CCC[C@H]1C(=O)N1CCN(CC1)c1nc(N)c2cc(OC)c(OC...    Tr
# 1088                               O1c2c(C=CC1=O)cccc2     Tr
# 1089                          Clc1cccc(Cl)c1C=NN=C(N)N     Te
# 1090   OC1(CCC2C3C(C4(C(=CC(=O)CC4)CC3)C)C(O)CC12C)C...    Tr
#
#                                              DESCRIPTOR   LOGD  \
# 0          1     0     0     0     0     0     0    ... -0.960
# 1          1     0     0     0     0     0     0    ... -0.920
# 2          1     0     0     0     0     0     0    ... -0.900
# 3          1     0     0     0     0     0     0    ... -0.830
# 4          1     0     0     0     0     0     0    ... -0.820
# ...                                                 ...    ...
# 1086       1     0     0     0     0     0     0    ...  1.000
# 1087       1     0     0     0     0     0     0    ...  1.140
# 1088       1     0     0     0     0     0     0    ...  1.415
# 1089       1     0     0     0     0     0     0    ...  1.670
# 1090       1     0     0     0     0     0     0    ...  1.530
#
#                                                     mol  AM1_dipole  \
# 0         Fc1c(N2CCNCC2)cc2N(C3CC3)C=C(C(=O)O)C(=O)c2c1    7.750276
# 1             O=S1(=O)N(C)CCN1c1cc2c(CCN(C)C)c[nH]c2cc1    4.358144
# 2                              O=C1C(O)=C(C)N(CCCO)C=C1    5.544390
# 3     Fc1c(N2CCNCC2)cc2N(c3c(C)cccc3)C=C(C(=O)O)C(=O...    8.887918
# 4                        O=C(NCC)CCN1C(C)=C(O)C(=O)C=C1    6.219123
# ...                                                 ...         ...
# 1086                 O(C[C@@H](O)CNC(C)C)c1c(CC=C)cccc1    0.588812
# 1087  O=C(N1CCN(c2nc(N)c3c(n2)cc(OC)c(OC)c3)CC1)[C@H...    2.551292
# 1088                                O=C1Oc2c(cccc2)C=C1    4.817789
# 1089                      Clc1c(C=N/N=C(\N)/N)c(Cl)ccc1    2.182817
# 1090  O=C(CO)[C@@]1(O)[C@@]2(C)[C@@H]([C@@H]3[C@@H](...    5.605708
#
#            AM1_E   AM1_Eele  ...  vsurf_Wp3  vsurf_Wp4  vsurf_Wp5  vsurf_Wp6  \
# 0    -103541.820 -717900.81  ...     75.625     12.500      4.500      0.625
# 1     -89582.016 -649679.25  ...     74.125     10.500      2.500      0.000
# 2     -57643.316 -300930.34  ...     29.625      6.125      1.125      0.000
# 3    -116000.170 -883984.06  ...     84.375     11.500      4.125      0.625
# 4     -69271.062 -395500.38  ...     56.875     14.125      3.125      0.000
# ...          ...        ...  ...        ...        ...        ...        ...
# 1086  -71140.453 -470514.53  ...     56.500     14.250      3.625      0.750
# 1087 -117421.360 -903435.00  ...    126.125     25.375      8.875      1.375
# 1088  -43230.504 -196975.89  ...      2.875      0.000      0.000      0.000
# 1089  -62454.488 -308495.69  ...    156.875     43.875     12.250      0.875
# 1090 -108510.510 -940109.25  ...     55.375     11.625      2.375      0.000
#
#       vsurf_Wp7  vsurf_Wp8     Weight  weinerPath  weinerPol  zagreb
# 0           0.0        0.0  331.34698        1234         43     134
# 1           0.0        0.0  322.43298        1055         35     120
# 2           0.0        0.0  183.20700         254         18      60
# 3           0.0        0.0  381.40698        1842         51     152
# 4           0.0        0.0  224.25999         483         22      74
# ...         ...        ...        ...         ...        ...     ...
# 1086        0.0        0.0  249.35399         711         21      80
# 1087        0.0        0.0  387.44000        2195         47     150
# 1088        0.0        0.0  146.14499         144         14      56
# 1089        0.0        0.0  231.08600         331         17      64
# 1090        0.0        0.0  362.46600        1425         59     154
#
# [1091 rows x 361 columns]

# %%
#1
merged_dataframe_MOEnostri = merged_dataframe_MOEnostri[merged_dataframe_MOEnostri['UNIQUEID'] != 'A-logD7.4-131']
print(merged_dataframe_MOEnostri.shape)
#2
merged_dataframe_MOEnostri = merged_dataframe_MOEnostri[merged_dataframe_MOEnostri['UNIQUEID'] != 'A-logD7.4-148']
print(merged_dataframe_MOEnostri.shape)
#3
merged_dataframe_MOEnostri = merged_dataframe_MOEnostri[merged_dataframe_MOEnostri['UNIQUEID'] != 'A-logD7.4-192']
print(merged_dataframe_MOEnostri.shape)
#4
merged_dataframe_MOEnostri = merged_dataframe_MOEnostri[merged_dataframe_MOEnostri['UNIQUEID'] != 'A-logD7.4-251']
print(merged_dataframe_MOEnostri.shape)
#5
merged_dataframe_MOEnostri = merged_dataframe_MOEnostri[merged_dataframe_MOEnostri['UNIQUEID'] != 'A-logD7.4-313']
print(merged_dataframe_MOEnostri.shape)
#6
merged_dataframe_MOEnostri = merged_dataframe_MOEnostri[merged_dataframe_MOEnostri['UNIQUEID'] != 'A-logD7.4-318']
print(merged_dataframe_MOEnostri.shape)
#7
merged_dataframe_MOEnostri = merged_dataframe_MOEnostri[merged_dataframe_MOEnostri['UNIQUEID'] != 'A-logD7.4-319']
print(merged_dataframe_MOEnostri.shape)
#8
merged_dataframe_MOEnostri = merged_dataframe_MOEnostri[merged_dataframe_MOEnostri['UNIQUEID'] != 'A-logD7.4-327']
print(merged_dataframe_MOEnostri.shape)
#9
merged_dataframe_MOEnostri = merged_dataframe_MOEnostri[merged_dataframe_MOEnostri['UNIQUEID'] != 'A-logD7.4-331']
print(merged_dataframe_MOEnostri.shape)
#10
merged_dataframe_MOEnostri = merged_dataframe_MOEnostri[merged_dataframe_MOEnostri['UNIQUEID'] != 'A-logD7.4-558']
print(merged_dataframe_MOEnostri.shape)
#11
merged_dataframe_MOEnostri = merged_dataframe_MOEnostri[merged_dataframe_MOEnostri['UNIQUEID'] != 'O-174']
print(merged_dataframe_MOEnostri.shape)
#12
merged_dataframe_MOEnostri = merged_dataframe_MOEnostri[merged_dataframe_MOEnostri['UNIQUEID'] != 'O-175']
print(merged_dataframe_MOEnostri.shape)
#13
merged_dataframe_MOEnostri = merged_dataframe_MOEnostri[merged_dataframe_MOEnostri['UNIQUEID'] != 'O-177']
print(merged_dataframe_MOEnostri.shape)
# Out:
# (1090, 361)
# (1089, 361)
# (1088, 361)
# (1087, 361)
# (1086, 361)
# (1085, 361)
# (1084, 361)
# (1083, 361)
# (1082, 361)
# (1081, 361)
# (1080, 361)
# (1079, 361)
# (1078, 361)

# %%
merged_dataframe_MOEnostri.to_csv("MOE_GRID_UNIFICATO_1078.csv")

# %%
file_2 = './data/MOE_GRID_UNIFICATO_1078.csv'

df2 = pd.read_csv(file_2)

rd = {" SMILE": "SMILE", " SETID" : "SETID", " DESCRIPTOR": "GRID_DESCRIPTOR", " LOGD" : "LOGD"}
df2.rename(columns = rd, inplace = True)

for v in df2.columns:
    print("\""+v+"\"")
# Out:
# "Unnamed: 0"
# "Unnamed: 0.1"
# "UNIQUEID"
# "SMILE"
# "SETID"
# "GRID_DESCRIPTOR"
# "LOGD"
# "mol"
# "AM1_dipole"
# "AM1_E"
# "AM1_Eele"
# "AM1_HF"
# "AM1_HOMO"
# "AM1_IP"
# "AM1_LUMO"
# "apol"
# "ASA"
# "ASA+"
# "ASA-"
# "ASA_H"
# "ASA_P"
# "ast_fraglike"
# "ast_fraglike_ext"
# "ast_violation"
# "ast_violation_ext"
# "a_acc"
# "a_acid"
# "a_aro"
# "a_base"
# "a_count"
# "a_don"
# "a_donacc"
# "a_heavy"
# "a_hyd"
# "a_IC"
# "a_ICM"
# "a_nB"
# "a_nBr"
# "a_nC"
# "a_nCl"
# "a_nF"
# "a_nH"
# "a_nI"
# "a_nN"
# "a_nO"
# "a_nP"
# "a_nS"
# "balabanJ"
# "BCUT_PEOE_0"
# "BCUT_PEOE_1"
# "BCUT_PEOE_2"
# "BCUT_PEOE_3"
# "BCUT_SLOGP_0"
# "BCUT_SLOGP_1"
# "BCUT_SLOGP_2"
# "BCUT_SLOGP_3"
# "BCUT_SMR_0"
# "BCUT_SMR_1"
# "BCUT_SMR_2"
# "BCUT_SMR_3"
# "bpol"
# "b_1rotN"
# "b_1rotR"
# "b_ar"
# "b_count"
# "b_double"
# "b_heavy"
# "b_max1len"
# "b_rotN"
# "b_rotR"
# "b_single"
# "b_triple"
# "CASA+"
# "CASA-"
# "chi0"
# "chi0v"
# "chi0v_C"
# "chi0_C"
# "chi1"
# "chi1v"
# "chi1v_C"
# "chi1_C"
# "chiral"
# "chiral_u"
# "DASA"
# "DCASA"
# "dens"
# "density"
# "diameter"
# "dipole"
# "dipoleX"
# "dipoleY"
# "dipoleZ"
# "E"
# "E_ang"
# "E_ele"
# "E_nb"
# "E_oop"
# "E_rele"
# "E_rnb"
# "E_rsol"
# "E_rvdw"
# "E_sol"
# "E_stb"
# "E_str"
# "E_strain"
# "E_tor"
# "E_vdw"
# "FASA+"
# "FASA-"
# "FASA_H"
# "FASA_P"
# "FCASA+"
# "FCASA-"
# "FCharge"
# "GCUT_PEOE_0"
# "GCUT_PEOE_1"
# "GCUT_PEOE_2"
# "GCUT_PEOE_3"
# "GCUT_SLOGP_0"
# "GCUT_SLOGP_1"
# "GCUT_SLOGP_2"
# "GCUT_SLOGP_3"
# "GCUT_SMR_0"
# "GCUT_SMR_1"
# "GCUT_SMR_2"
# "GCUT_SMR_3"
# "glob"
# "h_ema"
# "h_emd"
# "h_emd_C"
# "h_logD"
# "h_logP"
# "h_logS"
# "h_log_dbo"
# "h_log_pbo"
# "h_mr"
# "h_pavgQ"
# "h_pKa"
# "h_pKb"
# "h_pstates"
# "h_pstrain"
# "Kier1"
# "Kier2"
# "Kier3"
# "KierA1"
# "KierA2"
# "KierA3"
# "KierFlex"
# "lip_acc"
# "lip_don"
# "lip_druglike"
# "lip_violation"
# "logP(o/w)"
# "logS"
# "MNDO_dipole"
# "MNDO_E"
# "MNDO_Eele"
# "MNDO_HF"
# "MNDO_HOMO"
# "MNDO_IP"
# "MNDO_LUMO"
# "mr"
# "mutagenic"
# "nmol"
# "npr1"
# "npr2"
# "opr_brigid"
# "opr_leadlike"
# "opr_nring"
# "opr_nrot"
# "opr_violation"
# "PC+"
# "PC-"
# "PEOE_PC+"
# "PEOE_PC-"
# "PEOE_RPC+"
# "PEOE_RPC-"
# "PEOE_VSA+0"
# "PEOE_VSA+1"
# "PEOE_VSA+2"
# "PEOE_VSA+3"
# "PEOE_VSA+4"
# "PEOE_VSA+5"
# "PEOE_VSA+6"
# "PEOE_VSA-0"
# "PEOE_VSA-1"
# "PEOE_VSA-2"
# "PEOE_VSA-3"
# "PEOE_VSA-4"
# "PEOE_VSA-5"
# "PEOE_VSA-6"
# "PEOE_VSA_FHYD"
# "PEOE_VSA_FNEG"
# "PEOE_VSA_FPNEG"
# "PEOE_VSA_FPOL"
# "PEOE_VSA_FPOS"
# "PEOE_VSA_FPPOS"
# "PEOE_VSA_HYD"
# "PEOE_VSA_NEG"
# "PEOE_VSA_PNEG"
# "PEOE_VSA_POL"
# "PEOE_VSA_POS"
# "PEOE_VSA_PPOS"
# "petitjean"
# "petitjeanSC"
# "PM3_dipole"
# "PM3_E"
# "PM3_Eele"
# "PM3_HF"
# "PM3_HOMO"
# "PM3_IP"
# "PM3_LUMO"
# "pmi"
# "pmi1"
# "pmi2"
# "pmi3"
# "pmiX"
# "pmiY"
# "pmiZ"
# "Q_PC+"
# "Q_PC-"
# "Q_RPC+"
# "Q_RPC-"
# "Q_VSA_FHYD"
# "Q_VSA_FNEG"
# "Q_VSA_FPNEG"
# "Q_VSA_FPOL"
# "Q_VSA_FPOS"
# "Q_VSA_FPPOS"
# "Q_VSA_HYD"
# "Q_VSA_NEG"
# "Q_VSA_PNEG"
# "Q_VSA_POL"
# "Q_VSA_POS"
# "Q_VSA_PPOS"
# "radius"
# "reactive"
# "rgyr"
# "rings"
# "RPC+"
# "RPC-"
# "rsynth"
# "SlogP"
# "SlogP_VSA0"
# "SlogP_VSA1"
# "SlogP_VSA2"
# "SlogP_VSA3"
# "SlogP_VSA4"
# "SlogP_VSA5"
# "SlogP_VSA6"
# "SlogP_VSA7"
# "SlogP_VSA8"
# "SlogP_VSA9"
# "SMR"
# "SMR_VSA0"
# "SMR_VSA1"
# "SMR_VSA2"
# "SMR_VSA3"
# "SMR_VSA4"
# "SMR_VSA5"
# "SMR_VSA6"
# "SMR_VSA7"
# "std_dim1"
# "std_dim2"
# "std_dim3"
# "TPSA"
# "VAdjEq"
# "VAdjMa"
# "VDistEq"
# "VDistMa"
# "vdw_area"
# "vdw_vol"
# "vol"
# "VSA"
# "vsa_acc"
# "vsa_acid"
# "vsa_base"
# "vsa_don"
# "vsa_hyd"
# "vsa_other"
# "vsa_pol"
# "vsurf_A"
# "vsurf_CP"
# "vsurf_CW1"
# "vsurf_CW2"
# "vsurf_CW3"
# "vsurf_CW4"
# "vsurf_CW5"
# "vsurf_CW6"
# "vsurf_CW7"
# "vsurf_CW8"
# "vsurf_D1"
# "vsurf_D2"
# "vsurf_D3"
# "vsurf_D4"
# "vsurf_D5"
# "vsurf_D6"
# "vsurf_D7"
# "vsurf_D8"
# "vsurf_DD12"
# "vsurf_DD13"
# "vsurf_DD23"
# "vsurf_DW12"
# "vsurf_DW13"
# "vsurf_DW23"
# "vsurf_EDmin1"
# "vsurf_EDmin2"
# "vsurf_EDmin3"
# "vsurf_EWmin1"
# "vsurf_EWmin2"
# "vsurf_EWmin3"
# "vsurf_G"
# "vsurf_HB1"
# "vsurf_HB2"
# "vsurf_HB3"
# "vsurf_HB4"
# "vsurf_HB5"
# "vsurf_HB6"
# "vsurf_HB7"
# "vsurf_HB8"
# "vsurf_HL1"
# "vsurf_HL2"
# "vsurf_ID1"
# "vsurf_ID2"
# "vsurf_ID3"
# "vsurf_ID4"
# "vsurf_ID5"
# "vsurf_ID6"
# "vsurf_ID7"
# "vsurf_ID8"
# "vsurf_IW1"
# "vsurf_IW2"
# "vsurf_IW3"
# "vsurf_IW4"
# "vsurf_IW5"
# "vsurf_IW6"
# "vsurf_IW7"
# "vsurf_IW8"
# "vsurf_R"
# "vsurf_S"
# "vsurf_V"
# "vsurf_W1"
# "vsurf_W2"
# "vsurf_W3"
# "vsurf_W4"
# "vsurf_W5"
# "vsurf_W6"
# "vsurf_W7"
# "vsurf_W8"
# "vsurf_Wp1"
# "vsurf_Wp2"
# "vsurf_Wp3"
# "vsurf_Wp4"
# "vsurf_Wp5"
# "vsurf_Wp6"
# "vsurf_Wp7"
# "vsurf_Wp8"
# "Weight"
# "weinerPath"
# "weinerPol"
# "zagreb"

# %%
list_of_desc = ["a_acc", \
                  "a_base", \
                  "bpol", \
                  "b_double", \
                  "b_rotN", \
                  "b_rotR", \
                  "chi1_C", \
                  "diameter", \
                  "logP(o/w)", \
                  "logS", \
                  "PEOE_VSA+0", \
                  "PEOE_VSA+3", \
                  "PEOE_VSA-0", \
                  "PEOE_VSA-2", \
                  "PEOE_VSA-5", \
                  "PEOE_VSA_POS", \
                  "SlogP_VSA0", \
                  "SlogP_VSA1", \
                  "SlogP_VSA2", \
                  "SlogP_VSA3", \
                  "SlogP_VSA4", \
                  "SlogP_VSA8", \
                  "SMR_VSA1", \
                  "SMR_VSA6", \
                  "TPSA", \
                  "vsa_acc", \
                  "vsa_other", \
                  "vsa_pol", \
                  "weinerPol", \
                  "GRID_DESCRIPTOR"]
import numpy as np 

X = []
Y = []
setid = []
uniqueid = []
for idx, ss in enumerate(df2["UNIQUEID"]):
    
    fdesc = df2[df2["UNIQUEID"] == ss]
    
    xval = []
    for d in list_of_desc:
        if d == "GRID_DESCRIPTOR":
            nvs = fdesc[d].values[0].split()
            xval.extend([float(nv) for nv in nvs])
        else:
            xval.append(fdesc[d].values[0])

    X.append(xval)
    Y.append(df2[df2["UNIQUEID"] == ss]['LOGD'].values[0])
    setid.append(df2[df2["UNIQUEID"] == ss]['SETID'].values[0])
    uniqueid.append(df2[df2["UNIQUEID"] == ss]['UNIQUEID'].values[0])

print(np.asarray(Y).shape, np.asarray(X).shape )
# Out:
# (1078,) (1078, 1908)

# %%
Xtr = []
Xte = []
Ytr = []
Yte = []
for idx, y in enumerate(Y):
    if setid[idx] == " Tr ":
        Xtr.append(X[idx])
        Ytr.append(Y[idx])
    elif setid[idx] == " Te ":
        Xte.append(X[idx])
        Yte.append(Y[idx])
        
print("    Test set: ", len(Yte), len(Xte))
print("Training set: ", len(Ytr), len(Xtr))
# Out:
#     Test set:  213 213
# Training set:  865 865

# %%
# valutazione del numero di componenti principali ideale da usare per costruire il modello PLS (SENZA il descrittore nmol )
from sklearn.cross_decomposition import PLSRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import cross_val_predict
import numpy as np
import matplotlib.pyplot as plt

trscores = []
trmses = []
trncomps = []
for trncomp in range(1,20):
    pls = PLSRegression(trncomp)
    pls.fit(Xtr, Ytr)
    
    y_cv = cross_val_predict(pls, Xtr, Ytr, cv=10)
    
    trscore = r2_score(Ytr, y_cv)
    trmse = mean_squared_error(Ytr, y_cv)
    
    trscores.append(trscore)
    trmses.append(trmse)
    trncomps.append(trncomp)
    print("%4d %10.8f %10.8f"%(trncomp, trmse, trscore))
    
msetrmin = np.argmin(trmses)
print("Suggested number of components tr: ", msetrmin+1)
    
plt.plot(trncomps, trscores, '-o', color='black')
plt.xlabel('number of components tr')
plt.ylabel('scores tr')
plt.xticks(trncomps)
plt.show()

plt.plot(trncomps, trmses, '-o', color='black')
plt.xlabel('number of components tr')
plt.ylabel('MSE tr')
plt.xticks(trncomps)
plt.show()
# Out:
#    1 1.66208502 0.52497290
#    2 1.14639821 0.67235719
#    3 0.94596183 0.72964229
#    4 0.84649472 0.75807018
#    5 0.81182879 0.76797777
#    6 0.80697799 0.76936414
#    7 0.81110362 0.76818502
#    8 0.80950744 0.76864122
#    9 0.81028199 0.76841985
#   10 0.81138529 0.76810452
#   11 0.81210068 0.76790006
#   12 0.81240571 0.76781289
#   13 0.81228013 0.76784878
#   14 0.81233261 0.76783378
#   15 0.81235022 0.76782874
#   16 0.81238379 0.76781915
#   17 0.81237426 0.76782188
#   18 0.81237566 0.76782147
#   19 0.81237609 0.76782135
# Suggested number of components tr:  6

# %%
ncompsugg = 6

pls_6 = PLSRegression(ncompsugg)
pls_6.fit(Xtr, Ytr)
    
y_cv6 = cross_val_predict(pls_6, Xtr, Ytr, cv=10)
    
score6cv = r2_score(Ytr, y_cv6)
mse6cv = mean_squared_error(Ytr, y_cv6)    

print("comp: %4d MSE: %10.8f score: %10.8f"%(ncompsugg, mse6cv, score6cv))
# Out:
# comp:    6 MSE: 0.80697799 score: 0.76936414

# %%
ncompocchio = 4

pls_4 = PLSRegression(ncompocchio)
pls_4.fit(Xtr, Ytr)
    
y_cv4 = cross_val_predict(pls_4, Xtr, Ytr, cv=10)
    
score4cv = r2_score(Ytr, y_cv4)
mse4cv = mean_squared_error(Ytr, y_cv4)    

print("comp: %4d MSE: %10.8f score: %10.8f"%(ncompocchio, mse4cv, score4cv))
# Out:
# comp:    4 MSE: 0.84649472 score: 0.75807018

# %%
Y_pred6 = pls_6.predict(Xte)
Y_pred4 = pls_4.predict(Xte)

Y_pred6_TR = pls_6.predict(Xtr)
Y_pred4_TR = pls_4.predict(Xtr)

Y_pred6_Tot = pls_6.predict(X)
Y_pred4_Tot = pls_4.predict(X)


mse_pred6 = mean_squared_error(Yte, Y_pred6 )

RMSE_pred6 = mean_squared_error(Yte, Y_pred6, squared = False )

mse_pred4 = mean_squared_error(Yte, Y_pred4 )

RMSE_pred4 = mean_squared_error(Yte, Y_pred4, squared = False )


diff6 = []
diff4 =[]

for idx, val in enumerate(Yte):
    diff6.append(val-Y_pred6[idx])
    diff4.append(val-Y_pred4[idx])
    print("%10.7f %10.7f %10.7f %10.7f %10.7f"%(\
                                val, Y_pred6[idx], diff6[-1] ,Y_pred4[idx], diff4[-1] )) 
                            
score6 = r2_score(Yte, Y_pred6 )

score4 = r2_score(Yte, Y_pred4 )


print(" score modello a 6 componenti :", score6 )
print(" mse modello a 6 componenti :", mse_pred6)

print(" RMSE modello a 6 componenti :", RMSE_pred6)

print(" score modello a 4 componenti :", score4 )
print(" mse modello a 4 componenti :", mse_pred4)

print(" RMSE modello a 4 componenti :", RMSE_pred4)



plt.xlabel(" True Y value")
plt.ylabel(" Predicted Y values model built using 6 components) ")

plt.scatter(Yte, Y_pred6)

plt.show()

plt.xlabel(" True Y value")
# -1.7700000 -0.9966157 -0.7733843 -1.2460006 -0.5239994
#  4.3300000  3.5913322  0.7386678  3.7476011  0.5823989
# -0.0600000  0.7311844 -0.7911844  0.6756580 -0.7356580
#  1.3300000  1.8744851 -0.5444851  1.8957472 -0.5657472
# -0.2700000  0.2574463 -0.5274463  0.0045352 -0.2745352
#  3.4800000  2.9530101  0.5269899  2.7795643  0.7004357
# -0.2300000  0.5569549 -0.7869549  0.3655573 -0.5955573
#  0.0000000  0.5225405 -0.5225405  0.3559341 -0.3559341
# -0.2900000  0.1668019 -0.4568019 -0.0062869 -0.2837131
# -0.1000000  0.1605551 -0.2605551 -0.0437431 -0.0562569
#  0.3900000  0.2967852  0.0932148 -0.0394018  0.4294018
# -0.8700000 -0.0304660 -0.8395340 -0.2717909 -0.5982091
#  0.8600000  1.1572238 -0.2972238  1.1110310 -0.2510310
#  2.6100000  2.0474604  0.5625396  1.9682691  0.6417309
#  2.1000000  1.6627595  0.4372405  1.5121231  0.5878769
#  2.4400000  2.2760966  0.1639034  2.0522188  0.3877812
#  3.7100000  3.0520280  0.6579720  3.1123095  0.5976905
# -0.6000000 -0.0257221 -0.5742779  0.0881579 -0.6881579
#  0.1200000 -0.1650412  0.2850412 -0.1961213  0.3161213
#  2.4500000  2.4175727  0.0324273  2.4959029 -0.0459029
#  2.1000000  1.7947501  0.3052499  1.6076804  0.4923196
# -1.8500000 -1.7024306 -0.1475694 -1.8845745  0.0345745
#  2.1300000  1.8405221  0.2894779  1.7301119  0.3998881
# -0.7700000  0.5226631 -1.2926631  0.5121422 -1.2821422
# -0.5100000  0.1557881 -0.6657881  0.0629637 -0.5729637
# -1.2500000  0.0631566 -1.3131566  0.0428430 -1.2928430
#  0.3400000  2.0006669 -1.6606669  1.7756616 -1.4356616
#  4.1500000  3.6381170  0.5118830  3.5501669  0.5998331
#  3.4800000  2.9530101  0.5269899  2.7795643  0.7004357
#  1.4000000  1.3559395  0.0440605  1.2626616  0.1373384
#  1.6700000  1.4502665  0.2197335  1.4801480  0.1898520
#  score modello a 6 componenti : 0.8423627149500454
#  mse modello a 6 componenti : 0.4592278957725949
#  RMSE modello a 6 componenti : 0.6776635564737084
#  score modello a 4 componenti : 0.8347267418144064
#  mse modello a 4 componenti : 0.48147296218657354
#  RMSE modello a 4 componenti : 0.6938825276562118

# %%
# valutazione del numero di componenti principali ideale da usare per costruire il modello PLS (SENZA il descrittore nmol )
from sklearn.cross_decomposition import PLSRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import cross_val_predict
import numpy as np
import matplotlib.pyplot as plt

trscores = []
trmses = []
trcomps = []
for trcomp in range(1,20):
    pls = PLSRegression(trcomp)
    pls.fit(Xtr, Ytr)
    
    y_cv = cross_val_predict(pls, Xtr, Ytr, cv=5)
    
    trscore = r2_score(Ytr, y_cv)
    trmse = mean_squared_error(Ytr, y_cv)
    
    trscores.append(trscore)
    trmses.append(trmse)
    trcomps.append(trcomp)
    print("%4d %10.8f %10.8f"%(trcomp, trmse, trscore))
    
msetrmin = np.argmin(trmses)
print("Suggested number of components tr: ", msetrmin+1)
    
plt.plot(trcomps, trscores, '-o', color='black')
plt.xlabel('number of components tr')
plt.ylabel('scores tr')
plt.xticks(trcomps)
plt.show()

plt.plot(trcomps, trmses, '-o', color='black')
plt.xlabel('number of components tr')
plt.ylabel('MSE tr')
plt.xticks(trcomps)
plt.show()
# Out:
#    1 1.81725235 0.48062578
#    2 1.37748660 0.60631168
#    3 1.17212484 0.66500447
#    4 1.01729775 0.70925435
#    5 0.98458749 0.71860300
#    6 0.97946891 0.72006590
#    7 0.98360466 0.71888390
#    8 0.98997801 0.71706238
#    9 0.98990200 0.71708411
#   10 0.99101931 0.71676478
#   11 0.99066194 0.71686691
#   12 0.99065226 0.71686968
#   13 0.99051586 0.71690866
#   14 0.99067181 0.71686409
#   15 0.99078888 0.71683063
#   16 0.99077000 0.71683603
#   17 0.99075943 0.71683905
#   18 0.99075286 0.71684093
#   19 0.99076411 0.71683771
# Suggested number of components tr:  6

# %%
compsugg = 6

pls_6_cv5 = PLSRegression(compsugg)
pls_6_cv5.fit(Xtr, Ytr)
    
y_6_cv5 = cross_val_predict(pls_6_cv5, Xtr, Ytr, cv=5)
    
score6cv5 = r2_score(Ytr, y_6_cv5)
mse6cv5 = mean_squared_error(Ytr, y_6_cv5)    

print("comp: %4d MSE: %10.8f score: %10.8f"%(compsugg, mse6cv5, score6cv5))
# Out:
# comp:    6 MSE: 0.97946891 score: 0.72006590

# %%
compOCCHIO = 5

pls_5_cv5 = PLSRegression(compOCCHIO)
pls_5_cv5.fit(Xtr, Ytr)
    
y_5_cv5 = cross_val_predict(pls_5_cv5, Xtr, Ytr, cv=5)
    
score5cv5 = r2_score(Ytr, y_5_cv5)
mse5cv5 = mean_squared_error(Ytr, y_5_cv5)    

print("comp: %4d MSE: %10.8f score: %10.8f"%(compOCCHIO, mse5cv5, score5cv5))
# Out:
# comp:    5 MSE: 0.98458749 score: 0.71860300

# %%
Y_pred6_cv5 = pls_6_cv5.predict(Xte)
Y_pred5_cv5 = pls_5_cv5.predict(Xte)

Y_pred6_TR_cv5 = pls_6_cv5.predict(Xtr)
Y_pred5_TR_cv5 = pls_5_cv5.predict(Xtr)

Y_pred6_Tot_cv5 = pls_6_cv5.predict(X)
Y_pred5_Tot_cv5 = pls_5_cv5.predict(X)


mse_pred6_cv5 = mean_squared_error(Yte, Y_pred6_cv5 )

RMSE_pred6_cv5 = mean_squared_error(Yte, Y_pred6_cv5, squared = False )

mse_pred5_cv5 = mean_squared_error(Yte, Y_pred5_cv5 )

RMSE_pred5_cv5 = mean_squared_error(Yte, Y_pred5_cv5, squared = False )


diff6_cv5 = []
diff5_cv5 =[]

for idx, val in enumerate(Yte):
    diff6_cv5.append(val-Y_pred6_cv5[idx])
    diff5_cv5.append(val-Y_pred5_cv5[idx])
    print("%10.7f %10.7f %10.7f %10.7f %10.7f"%(\
                                val, Y_pred6_cv5[idx], diff6_cv5[-1] ,Y_pred5_cv5[idx], diff5_cv5[-1] )) 
                            
score6_cv5 = r2_score(Yte, Y_pred6_cv5 )

score5_cv5 = r2_score(Yte, Y_pred5_cv5 )


print(" score modello a 6 componenti :", score6_cv5 )
print(" mse modello a 6 componenti :", mse_pred6_cv5)

print(" RMSE modello a 6 componenti :", RMSE_pred6_cv5)

print(" score modello a 5 componenti :", score5_cv5 )
print(" mse modello a 5 componenti :", mse_pred5_cv5)

print(" RMSE modello a 5 componenti :", RMSE_pred5_cv5)



plt.xlabel(" True Y value")
plt.ylabel(" Predicted Y values model built using 6 components) ")

plt.scatter(Yte, Y_pred6_cv5)

plt.show()

plt.xlabel(" True Y value")
plt.ylabel(" Predicted Y values model built using 5 components) ")

plt.scatter(Yte, Y_pred5_cv5)

plt.show()
# Out:
# -0.7400000  0.6563857 -1.3963857  0.7220779 -1.4620779
# -0.6800000 -0.2514829 -0.4285171 -0.2179634 -0.4620366
# -0.5000000  0.3509399 -0.8509399  0.3137214 -0.8137214
# -0.3900000 -0.2449090 -0.1450910 -0.2845449 -0.1054551
# -0.3400000 -0.3700075  0.0300075 -0.3293034 -0.0106966
# -0.2100000 -0.0271996 -0.1828004  0.0203765 -0.2303765
# -0.1900000 -0.4598633  0.2698633 -0.3034602  0.1134602
# -0.1300000  1.2710993 -1.4010993  1.3202686 -1.4502686
# -0.0400000  1.2025446 -1.2425446  1.1481095 -1.1881095
#  0.0500000  1.7062218 -1.6562218  1.7121398 -1.6621398
#  0.2000000  1.5517098 -1.3517098  1.4458541 -1.2458541
#  0.2100000 -0.0318631  0.2418631  0.0564900  0.1535100
#  0.3000000  0.4796361 -0.1796361  0.5013768 -0.2013768
#  0.4000000  0.8594515 -0.4594515  0.6599213 -0.2599213
#  0.6400000  1.4440145 -0.8040145  1.4532504 -0.8132504
#  0.6930000  0.6032312  0.0897688  0.5655527  0.1274473
#  0.9800000  1.4620927 -0.4820927  1.4251535 -0.4451535
#  1.1000000  2.0089345 -0.9089345  1.8852946 -0.7852946
#  1.1400000  1.4046158 -0.2646158  1.5082354 -0.3682354
#  1.2000000  2.0434193 -0.8434193  1.9860064 -0.7860064
#  1.2200000  0.9409052  0.2790948  0.9432829  0.2767171
#  1.2600000  1.4993694 -0.2393694  1.5383816 -0.2783816
# -1.9900000 -0.6713833 -1.3186167 -0.5952994 -1.3947006
#  1.3000000  1.7112583 -0.4112583  1.7273815 -0.4273815
#  1.3000000  1.4167332 -0.1167332  1.3067412 -0.0067412
#  1.5000000  2.1286621 -0.6286621  2.1926151 -0.6926151
#  1.6700000  2.1400183 -0.4700183  2.1072068 -0.4372068
#  1.6000000  1.6476310 -0.0476310  1.6241698 -0.0241698
#  1.6000000  1.0921157  0.5078843  0.8962573  0.7037427
#  1.6400000  1.9036865 -0.2636865  1.9780969 -0.3380969
#  1.7000000  1.4776346  0.2223654  1.5785900  0.1214100
#  1.7000000  2.0785467 -0.3785467  2.1220720 -0.4220720
#  1.7000000  1.3471409  0.3528591  1.2118381  0.4881619
#  1.7600000  1.8489732 -0.0889732  1.9291148 -0.1691148
