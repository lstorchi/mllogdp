# %%
import pandas as pd
file = './data/MOE_GRID_1078.xlsx'
df = pd.read_excel(open(file, "rb"))

rd = {"DESCRIPTOR" : "GRID_DESCRIPTOR"}
df.rename(columns = rd, inplace=True)

for v in df.columns:
    print("\""+v+"\"")
# Out:
# "Unnamed: 0"
# "Unnamed: 0.1"
# "UNIQUEID"
# "SMILE"
# "SETID"
# "GRID_DESCRIPTOR"
# "LOGD"
# "mol"
# "AM1_dipole"
# "AM1_E"
# "AM1_Eele"
# "AM1_HF"
# "AM1_HOMO"
# "AM1_IP"
# "AM1_LUMO"
# "apol"
# "ASA"
# "ASA+"
# "ASA-"
# "ASA_H"
# "ASA_P"
# "ast_fraglike"
# "ast_fraglike_ext"
# "ast_violation"
# "ast_violation_ext"
# "a_acc"
# "a_acid"
# "a_aro"
# "a_base"
# "a_count"
# "a_don"
# "a_donacc"
# "a_heavy"
# "a_hyd"
# "a_IC"
# "a_ICM"
# "a_nB"
# "a_nBr"
# "a_nC"
# "a_nCl"
# "a_nF"
# "a_nH"
# "a_nI"
# "a_nN"
# "a_nO"
# "a_nP"
# "a_nS"
# "balabanJ"
# "BCUT_PEOE_0"
# "BCUT_PEOE_1"
# "BCUT_PEOE_2"
# "BCUT_PEOE_3"
# "BCUT_SLOGP_0"
# "BCUT_SLOGP_1"
# "BCUT_SLOGP_2"
# "BCUT_SLOGP_3"
# "BCUT_SMR_0"
# "BCUT_SMR_1"
# "BCUT_SMR_2"
# "BCUT_SMR_3"
# "bpol"
# "b_1rotN"
# "b_1rotR"
# "b_ar"
# "b_count"
# "b_double"
# "b_heavy"
# "b_max1len"
# "b_rotN"
# "b_rotR"
# "b_single"
# "b_triple"
# "CASA+"
# "CASA-"
# "chi0"
# "chi0v"
# "chi0v_C"
# "chi0_C"
# "chi1"
# "chi1v"
# "chi1v_C"
# "chi1_C"
# ...

# %%
df_dataframe = pd.DataFrame(df)
df_dataframe
# Out:
#       Unnamed: 0  Unnamed: 0.1       UNIQUEID  \
# 0              0             0  A-logD7.4-100
# 1              1             1  A-logD7.4-101
# 2              2             2  A-logD7.4-104
# 3              3             3  A-logD7.4-105
# 4              4             4  A-logD7.4-106
# ...          ...           ...            ...
# 1073        1086          1086           O-88
# 1074        1087          1087            O-9
# 1075        1088          1088           O-94
# 1076        1089          1089           O-97
# 1077        1090          1090           O-98
#
#                                                   SMILE SETID  \
# 0           Fc1cc2c(N(C=C(C(O)=O)C2=O)C2CC2)cc1N1CCNCC1    Tr
# 1           S1(=O)(=O)N(CCN1C)c1cc2c([nH]cc2CCN(C)C)cc1    Tr
# 2                               OC=1C(=O)C=CN(CCCO)C=1C    Tr
# 3       Fc1cc2c(N(C=C(C(O)=O)C2=O)c2ccccc2C)cc1N1CCNCC1    Tr
# 4                         OC=1C(=O)C=CN(CCC(=O)NCC)C=1C    Tr
# ...

# %%
GRID_UNIQUE_dataframe = df[["UNIQUEID","GRID_DESCRIPTOR"]]
GRID_UNIQUE_dataframe
# Out:
#            UNIQUEID                                    GRID_DESCRIPTOR
# 0     A-logD7.4-100  1     0     0     0     0     0     0     0   ...
# 1     A-logD7.4-101  1     0     0     0     0     0     0     0   ...
# 2     A-logD7.4-104  1     0     0     0     0     0     0     0   ...
# 3     A-logD7.4-105  1     0     0     0     0     0     0     0   ...
# 4     A-logD7.4-106  1     0     0     0     0     0     0     0   ...
# ...             ...                                                ...
# 1073           O-88  1     0     0     0     0     0     0     0   ...
# 1074            O-9  1     0     0     0     0     0     0     0   ...
# 1075           O-94  1     0     0     0     0     0     0     0   ...
# 1076           O-97  1     0     0     0     0     0     0     0   ...
# 1077           O-98  1     0     0     0     0     0     0     0   ...
#
# [1078 rows x 2 columns]

# %%
df_dataframe = df_dataframe.drop(["GRID_DESCRIPTOR"], axis=1)
df_dataframe
# Out:
#       Unnamed: 0  Unnamed: 0.1       UNIQUEID  \
# 0              0             0  A-logD7.4-100
# 1              1             1  A-logD7.4-101
# 2              2             2  A-logD7.4-104
# 3              3             3  A-logD7.4-105
# 4              4             4  A-logD7.4-106
# ...          ...           ...            ...
# 1073        1086          1086           O-88
# 1074        1087          1087            O-9
# 1075        1088          1088           O-94
# 1076        1089          1089           O-97
# 1077        1090          1090           O-98
#
#                                                   SMILE SETID   LOGD  \
# 0           Fc1cc2c(N(C=C(C(O)=O)C2=O)C2CC2)cc1N1CCNCC1    Tr -0.960
# 1           S1(=O)(=O)N(CCN1C)c1cc2c([nH]cc2CCN(C)C)cc1    Tr -0.920
# 2                               OC=1C(=O)C=CN(CCCO)C=1C    Tr -0.900
# 3       Fc1cc2c(N(C=C(C(O)=O)C2=O)c2ccccc2C)cc1N1CCNCC1    Tr -0.830
# ...

# %%
dataframe_parte_generale = df_dataframe[["Unnamed: 0","Unnamed: 0.1","UNIQUEID","SMILE","SETID","LOGD","mol"]]
dataframe_parte_generale
# Out:
#       Unnamed: 0  Unnamed: 0.1       UNIQUEID  \
# 0              0             0  A-logD7.4-100
# 1              1             1  A-logD7.4-101
# 2              2             2  A-logD7.4-104
# 3              3             3  A-logD7.4-105
# 4              4             4  A-logD7.4-106
# ...          ...           ...            ...
# 1073        1086          1086           O-88
# 1074        1087          1087            O-9
# 1075        1088          1088           O-94
# 1076        1089          1089           O-97
# 1077        1090          1090           O-98
#
#                                                   SMILE SETID   LOGD  \
# 0           Fc1cc2c(N(C=C(C(O)=O)C2=O)C2CC2)cc1N1CCNCC1    Tr -0.960
# 1           S1(=O)(=O)N(CCN1C)c1cc2c([nH]cc2CCN(C)C)cc1    Tr -0.920
# 2                               OC=1C(=O)C=CN(CCCO)C=1C    Tr -0.900
# 3       Fc1cc2c(N(C=C(C(O)=O)C2=O)c2ccccc2C)cc1N1CCNCC1    Tr -0.830
# ...

# %%
df_dataframe = df_dataframe.drop(["Unnamed: 0","Unnamed: 0.1","SMILE","SETID","LOGD","mol"], axis=1)
df_dataframe
# Out:
#            UNIQUEID  AM1_dipole       AM1_E   AM1_Eele      AM1_HF  AM1_HOMO  \
# 0     A-logD7.4-100    7.750276 -103541.820 -717900.81  -41.068192  -9.14368
# 1     A-logD7.4-101    4.358144  -89582.016 -649679.25    9.004830  -8.49724
# 2     A-logD7.4-104    5.544390  -57643.316 -300930.34 -109.097170  -8.43392
# 3     A-logD7.4-105    8.887918 -116000.170 -883984.06  -75.744698  -8.95637
# 4     A-logD7.4-106    6.219123  -69271.062 -395500.38  -95.149117  -8.47283
# ...             ...         ...         ...        ...         ...       ...
# 1073           O-88    0.588812  -71140.453 -470514.53  -52.989620  -8.96536
# 1074            O-9    2.551292 -117421.360 -903435.00  -66.937332  -8.41628
# 1075           O-94    4.817789  -43230.504 -196975.89  -30.297520  -9.46002
# 1076           O-97    2.182817  -62454.488 -308495.69   67.349892  -8.74139
# 1077           O-98    5.605708 -108510.510 -940109.25 -217.843980  -9.78824
#
# ...

# %%
desc_28_model = df_dataframe[["a_acc", \
                  "bpol", \
                  "b_double", \
                  "b_rotN", \
                  "b_rotR", \
                  "chi1_C", \
                  "diameter", \
                  "logP(o/w)", \
                  "logS", \
                  "PEOE_VSA+0", \
                  "PEOE_VSA+3", \
                  "PEOE_VSA-0", \
                  "PEOE_VSA-2", \
                  "PEOE_VSA-5", \
                  "PEOE_VSA_POS", \
                  "SlogP_VSA0", \
                  "SlogP_VSA1", \
                  "SlogP_VSA2", \
                  "SlogP_VSA3", \
                  "SlogP_VSA4", \
                  "SlogP_VSA8", \
                  "SMR_VSA1", \
                  "SMR_VSA6", \
                  "TPSA", \
                  "vsa_acc", \
                  "vsa_other", \
                  "vsa_pol", \
                  "weinerPol"]]
desc_28_model
# Out:
#       a_acc       bpol  b_double  b_rotN    b_rotR    chi1_C  diameter  \
# 0         4  27.416725         3       3  0.111111  6.024405        11
# 1         3  37.126553         0       4  0.166667  4.616157        11
# 2         3  17.149691         3       3  0.230769  3.152265         8
# 3         4  29.603140         3       3  0.096774  7.935088        11
# 4         3  22.047312         4       5  0.312500  3.767620        10
# ...     ...        ...       ...     ...       ...       ...       ...
# 1073      3  27.719761         1       8  0.444444  6.236382        11
# 1074      6  39.976173         1       5  0.161290  5.374575        15
# 1075      1   9.433242         2       0  0.000000  3.966327         6
# 1076      2   9.585656         2       2  0.142857  2.891411         8
# 1077      5  34.712212         3       2  0.068966  9.231347        12
#
#       logP(o/w)     logS  PEOE_VSA+0  ...  SlogP_VSA3  SlogP_VSA4  SlogP_VSA8  \
# ...

# %%
import sklearn 
import sklearn.preprocessing 
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
desc_28_model_SCALED = scaler.fit_transform(desc_28_model)
desc_28_model_SCALED_dataframe = pd.DataFrame(desc_28_model_SCALED)
desc_28_model_SCALED_dataframe
# Out:
#             0         1         2         3         4         5         6   \
# 0     0.028440 -0.265146  0.993272 -0.647367 -0.889783 -0.373959 -0.428553
# 1    -0.436076  0.341355 -1.103491 -0.453409 -0.417537 -0.837736 -0.428553
# 2    -0.436076 -0.906451  0.993272 -0.647367  0.127361 -1.319838 -1.023122
# 3     0.028440 -0.128577  0.993272 -0.647367 -1.011652  0.255285 -0.428553
# 4    -0.436076 -0.600533  1.692193 -0.259451  0.822106 -1.117184 -0.626743
# ...        ...       ...       ...       ...       ...       ...       ...
# 1073 -0.436076 -0.246217 -0.404570  0.322424  1.943688 -0.304148 -0.428553
# 1074  0.957470  0.519350 -0.404570 -0.259451 -0.463239 -0.587967  0.364206
# 1075 -1.365106 -1.388440  0.294351 -1.229243 -1.834273 -1.051744 -1.419501
# 1076 -0.900591 -1.378920  0.294351 -0.841326 -0.619928 -1.405745 -1.023122
# 1077  0.492955  0.190549  0.993272 -0.841326 -1.248037  0.682181 -0.230363
#
# ...

# %%
desc_28_model_SCALED_dataframe.rename(columns={0:"a_acc", 1:"bpol", 2:"b_double", 3:"b_rotN", 4:"b_rotR", 5:"chi1_C", 6:"diameter", 7:"logP(o/w)", 8:"logS", 9:"PEOE_VSA+0", 10:"PEOE_VSA+3", 11:"PEOE_VSA-0", 12:"PEOE_VSA-2", 13:"PEOE_VSA-5", 14:"PEOE_VSA_POS", 15:"SlogP_VSA0", 16:"SlogP_VSA1", 17:"SlogP_VSA2", 18:"SlogP_VSA3", 19:"SlogP_VSA4", 20:"SlogP_VSA8", 21:"SMR_VSA1", 22:"SMR_VSA6", 23:"TPSA", 24:"vsa_acc", 25:"vsa_other", 26:"vsa_pol", 27:"weinerPol"}, inplace=True)
Uniqueid = df_dataframe["UNIQUEID"]
desc_28_model_SCALED_dataframe = desc_28_model_SCALED_dataframe.join(Uniqueid)
desc_28_model_SCALED_dataframe
# Out:
#          a_acc      bpol  b_double    b_rotN    b_rotR    chi1_C  diameter  \
# 0     0.028440 -0.265146  0.993272 -0.647367 -0.889783 -0.373959 -0.428553
# 1    -0.436076  0.341355 -1.103491 -0.453409 -0.417537 -0.837736 -0.428553
# 2    -0.436076 -0.906451  0.993272 -0.647367  0.127361 -1.319838 -1.023122
# 3     0.028440 -0.128577  0.993272 -0.647367 -1.011652  0.255285 -0.428553
# 4    -0.436076 -0.600533  1.692193 -0.259451  0.822106 -1.117184 -0.626743
# ...        ...       ...       ...       ...       ...       ...       ...
# 1073 -0.436076 -0.246217 -0.404570  0.322424  1.943688 -0.304148 -0.428553
# 1074  0.957470  0.519350 -0.404570 -0.259451 -0.463239 -0.587967  0.364206
# 1075 -1.365106 -1.388440  0.294351 -1.229243 -1.834273 -1.051744 -1.419501
# 1076 -0.900591 -1.378920  0.294351 -0.841326 -0.619928 -1.405745 -1.023122
# 1077  0.492955  0.190549  0.993272 -0.841326 -1.248037  0.682181 -0.230363
#
# ...

# %%
desc_28_model_SCALED_dataframe = desc_28_model_SCALED_dataframe.iloc[:,:28]
desc_28_model_SCALED_dataframe
# Out:
#          a_acc      bpol  b_double    b_rotN    b_rotR    chi1_C  diameter  \
# 0     0.028440 -0.265146  0.993272 -0.647367 -0.889783 -0.373959 -0.428553
# 1    -0.436076  0.341355 -1.103491 -0.453409 -0.417537 -0.837736 -0.428553
# 2    -0.436076 -0.906451  0.993272 -0.647367  0.127361 -1.319838 -1.023122
# 3     0.028440 -0.128577  0.993272 -0.647367 -1.011652  0.255285 -0.428553
# 4    -0.436076 -0.600533  1.692193 -0.259451  0.822106 -1.117184 -0.626743
# ...        ...       ...       ...       ...       ...       ...       ...
# 1073 -0.436076 -0.246217 -0.404570  0.322424  1.943688 -0.304148 -0.428553
# 1074  0.957470  0.519350 -0.404570 -0.259451 -0.463239 -0.587967  0.364206
# 1075 -1.365106 -1.388440  0.294351 -1.229243 -1.834273 -1.051744 -1.419501
# 1076 -0.900591 -1.378920  0.294351 -0.841326 -0.619928 -1.405745 -1.023122
# 1077  0.492955  0.190549  0.993272 -0.841326 -1.248037  0.682181 -0.230363
#
# ...

# %%
from sklearn.decomposition import PCA
import numpy as np

pca = PCA( n_components=0.95 )
X_proj = pca.fit_transform( desc_28_model_SCALED_dataframe )
print( np.shape( X_proj ) )
X_proj = pd.DataFrame( X_proj )
print( X_proj )
# Out:
# (1078, 13)
#              0         1         2         3         4         5         6  \
# 0    -0.253594  0.783172 -1.014723 -1.652702  2.338411 -0.160004 -0.093332
# 1    -1.251696  0.092631  1.796386  0.623981  1.570765  3.915490  0.701274
# 2    -2.714870  1.318809  0.649645 -2.265820  0.760244  0.167095  0.118610
# 3     0.144719  0.092030 -1.425312 -0.831966  2.554562 -0.604875 -0.079185
# 4    -1.337547  1.985466 -0.283333 -2.337983  0.720121  0.878115 -0.692225
# ...        ...       ...       ...       ...       ...       ...       ...
# 1073 -1.939953 -1.154522  1.601222 -1.250122 -1.033221  1.286873  0.045143
# 1074  1.789291  0.962022  1.670411 -1.297409  1.523764 -0.062513  0.840744
# 1075 -4.675547  0.822298 -1.037941 -0.709812  0.050973 -0.028323  0.360673
# 1076 -2.868349  1.861227  0.467578  0.267220 -1.931430 -0.453213  0.334821
# 1077  1.189336  1.529506 -0.852155 -0.762534 -0.342740 -0.833892  2.843369
#
# ...

# %%
import matplotlib.pyplot as plt

plt.scatter( X_proj.iloc[:,0], X_proj.iloc[:,1] )
plt.xlabel("Componente 1")
plt.ylabel("Componente 2")
plt.grid()
plt.show()

# %%
desc_28_model_SCALED_dataframe = desc_28_model_SCALED_dataframe.iloc[:,:10]

# %%
def pca_map(X, figsize=(10,10), sup="", print_values= False):
    #PCA
    columns=X.columns.values
    pca=PCA(n_components=2)
    pca.fit(X)
    pca_values=pca.components_
    
    #Plot
    plt.figure(figsize=figsize)
    plt.rcParams.update({'font.size': 14}) 
    
    #Plot circle
    x=np.linspace(start=-1,stop=1,num=500)
    y_positive=lambda x: np.sqrt(1-x**2) 
    y_negative=lambda x: -np.sqrt(1-x**2)
    plt.plot(x,list(map(y_positive, x)), color='maroon')
    plt.plot(x,list(map(y_negative, x)),color='maroon')
    
    #Plot smaller circle
    x=np.linspace(start=-0.5,stop=0.5,num=500)
    y_positive=lambda x: np.sqrt(0.5**2-x**2) 
    y_negative=lambda x: -np.sqrt(0.5**2-x**2)
    plt.plot(x,list(map(y_positive, x)), color='maroon')
    plt.plot(x,list(map(y_negative, x)),color='maroon')
    
    #Create broken lines
    x=np.linspace(start=-1,stop=1,num=30)
    plt.scatter(x,[0]*len(x), marker='_',color='maroon')
    plt.scatter([0]*len(x), x, marker='|',color='maroon')

    #Define color list
    colors = ['blue', 'red', 'green', 'black', 'purple', 'brown']
    if len(pca_values[0]) > 6:
        colors=colors*(int(len(pca_values[0])/6)+1)

    #Plot arrow
    add_string=""
    for i in range(len(pca_values[0])):
        xi=pca_values[0][i]
        yi=pca_values[1][i]
        plt.arrow(0,0, 
                  dx=xi, dy=yi, 
                  head_width=0.03, head_length=0.03, 
                  color=colors[i], length_includes_head=True)
        if print_values==True:
            add_string=f" ({round(xi,2)} {round(yi,2)})"
        plt.text(pca_values[0, i], 
                 pca_values[1, i] , 
                 s=columns[i] + add_string )

    plt.xlabel(f"Component 1 ({round(pca.explained_variance_ratio_[0]*100,2)}%)")
    plt.ylabel(f"Component 2 ({round(pca.explained_variance_ratio_[1]*100,2)}%)")
    plt.title('Variable factor map (PCA)')
    plt.suptitle(sup, y=1, fontsize=18)
    plt.show()

# %%
pca_map(desc_28_model_SCALED_dataframe, figsize=(7,7), sup="Loadings plot using first 10 MOE variables")
