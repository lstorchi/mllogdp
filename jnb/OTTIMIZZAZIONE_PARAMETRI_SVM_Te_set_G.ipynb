# %%
# %%time
import pandas as pd
file = './data/MOE_GRID_1078.xlsx'
file_read = pd.read_excel(file)
file_dataframe = pd.DataFrame(file_read)
file_dataframe
# Out:
# CPU times: user 5.42 s, sys: 404 ms, total: 5.83 s
# Wall time: 7.71 s
#       Unnamed: 0  Unnamed: 0.1       UNIQUEID  \
# 0              0             0  A-logD7.4-100
# 1              1             1  A-logD7.4-101
# 2              2             2  A-logD7.4-104
# 3              3             3  A-logD7.4-105
# 4              4             4  A-logD7.4-106
# ...          ...           ...            ...
# 1073        1086          1086           O-88
# 1074        1087          1087            O-9
# 1075        1088          1088           O-94
# 1076        1089          1089           O-97
# 1077        1090          1090           O-98
#
#                                                   SMILE SETID  \
# 0           Fc1cc2c(N(C=C(C(O)=O)C2=O)C2CC2)cc1N1CCNCC1    Tr
# 1           S1(=O)(=O)N(CCN1C)c1cc2c([nH]cc2CCN(C)C)cc1    Tr
# 2                               OC=1C(=O)C=CN(CCCO)C=1C    Tr
# 3       Fc1cc2c(N(C=C(C(O)=O)C2=O)c2ccccc2C)cc1N1CCNCC1    Tr
# ...

# %%
# %%time
import numpy as np 
import string


list_of_desc = ["a_acc", \
                  "bpol", \
                  "b_double", \
                  "b_rotN", \
                  "b_rotR", \
                  "chi1_C", \
                  "diameter", \
                  "logP(o/w)", \
                  "logS", \
                  "PEOE_VSA+0", \
                  "PEOE_VSA+3", \
                  "PEOE_VSA-0", \
                  "PEOE_VSA-2", \
                  "PEOE_VSA-5", \
                  "PEOE_VSA_POS", \
                  "SlogP_VSA0", \
                  "SlogP_VSA1", \
                  "SlogP_VSA2", \
                  "SlogP_VSA3", \
                  "SlogP_VSA4", \
                  "SlogP_VSA8", \
                  "SMR_VSA1", \
                  "SMR_VSA6", \
                  "TPSA", \
                  "vsa_acc", \
                  "vsa_other", \
                  "vsa_pol", \
                  "weinerPol", \
                  "DESCRIPTOR"]
                
basicname = ["G", "M", "GM", \
             "GTr", "GTe", \
             "MTe", "MTr", \
             "GMTe", "GMTr"]

X = {}
Y = {}
setid = {}
uniqueid = {}

for bn in basicname:
    X[bn] = []
    Y[bn] = []
    setid[bn] = []
    uniqueid[bn] = []

for idx, ss in enumerate(file_read["UNIQUEID"]):
    
    fdesc = file_read[file_read["UNIQUEID"] == ss]
    
    xval = {}
    for bn in basicname:
        xval[bn] = []

    for d in list_of_desc:
        if d == "DESCRIPTOR":
            nvs = fdesc[d].values[0].split()
            xval["GM"].extend([float(nv) for nv in nvs])  
            xval["G"].extend([float(nv) for nv in nvs])  
            xval["GMTr"].extend([float(nv) for nv in nvs])  
            xval["GTr"].extend([float(nv) for nv in nvs])  
            xval["GMTe"].extend([float(nv) for nv in nvs])  
            xval["GTe"].extend([float(nv) for nv in nvs])  
        else:
            xval["GM"].append(fdesc[d].values[0])
            xval["M"].append(fdesc[d].values[0])
            xval["GMTr"].append(fdesc[d].values[0])
            xval["MTr"].append(fdesc[d].values[0])
            xval["GMTe"].append(fdesc[d].values[0])
            xval["MTe"].append(fdesc[d].values[0])
            
    y = file_read[file_read["UNIQUEID"] == ss]['LOGD'].values[0]
    sid = file_read[file_read["UNIQUEID"] == ss]['SETID'].values[0]
    uid = file_read[file_read["UNIQUEID"] == ss]['UNIQUEID'].values[0]
    
    for bn in ["GM", "G", "M"]:
        X[bn].append(xval[bn])
        Y[bn].append(y)
        setid[bn].append(sid)
        uniqueid[bn].append(uid)
        
    if (sid == "Tr"):
        for bn in ["GMTr", "GTr", "MTr"]:
            X[bn].append(xval[bn])
            Y[bn].append(y)
            setid[bn].append(sid)
            uniqueid[bn].append(uid)
    elif (sid == "Te"):
        for bn in ["GMTe", "GTe", "MTe"]:
            X[bn].append(xval[bn])
            Y[bn].append(y)
            setid[bn].append(sid)
            uniqueid[bn].append(uid)


for bn in basicname:
    print(bn, " : ")
    print("  ", np.asarray(Y[bn]).shape, np.asarray(X[bn]).shape )
# Out:
# G  :
#    (1078,) (1078, 1879)
# M  :
#    (1078,) (1078, 28)
# GM  :
#    (1078,) (1078, 1907)
# GTr  :
#    (865,) (865, 1879)
# GTe  :
#    (213,) (213, 1879)
# MTe  :
#    (213,) (213, 28)
# MTr  :
#    (865,) (865, 28)
# GMTe  :
#    (213,) (213, 1907)
# GMTr  :
#    (865,) (865, 1907)
# CPU times: user 13 s, sys: 249 ms, total: 13.2 s
# Wall time: 13.2 s

# %%
# %%time
import sklearn 
import sklearn.preprocessing 
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_G_SCALED_Tr = scaler.fit_transform(X['GTr'])
X_G_SCALED_Tr_dataframe = pd.DataFrame(X_G_SCALED_Tr)

X_G_SCALED_Te = scaler.fit_transform(X['GTe'])
X_G_SCALED_Te_dataframe = pd.DataFrame(X_G_SCALED_Te)
X_G_SCALED_Tr_dataframe
X_G_SCALED_Te_dataframe
# Out:
# CPU times: user 1.16 s, sys: 140 ms, total: 1.3 s
# Wall time: 4.23 s
#      0        1     2        3        4        5     6        7     8     \
# 0     0.0 -0.06868   0.0 -0.06868 -0.06868 -0.06868   0.0 -0.06868   0.0
# 1     0.0 -0.06868   0.0 -0.06868 -0.06868 -0.06868   0.0 -0.06868   0.0
# 2     0.0 -0.06868   0.0 -0.06868 -0.06868 -0.06868   0.0 -0.06868   0.0
# 3     0.0 -0.06868   0.0 -0.06868 -0.06868 -0.06868   0.0 -0.06868   0.0
# 4     0.0 -0.06868   0.0 -0.06868 -0.06868 -0.06868   0.0 -0.06868   0.0
# ..    ...      ...   ...      ...      ...      ...   ...      ...   ...
# 208   0.0 -0.06868   0.0 -0.06868 -0.06868 -0.06868   0.0 -0.06868   0.0
# 209   0.0 -0.06868   0.0 -0.06868 -0.06868 -0.06868   0.0 -0.06868   0.0
# 210   0.0 -0.06868   0.0 -0.06868 -0.06868 -0.06868   0.0 -0.06868   0.0
# 211   0.0 -0.06868   0.0 -0.06868 -0.06868 -0.06868   0.0 -0.06868   0.0
# 212   0.0 -0.06868   0.0 -0.06868 -0.06868 -0.06868   0.0 -0.06868   0.0
#
# ...

# %%
# %%time
Y_G_Tr = Y['GTr']
Y_G_Te = Y['GTe']
# Out:
# CPU times: user 6 µs, sys: 0 ns, total: 6 µs
# Wall time: 9.78 µs

# %%
# %%time
from sklearn import svm
from sklearn.svm import SVR
from sklearn import metrics
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_predict

gamma = ['scale','auto']
kernel = ['linear','sigmoid','rbf']
degree = [2,3,4,5,6,7,8,9,10]
C = [1,50,64,100,1000]
epsilon = [0.1,0.25,0.50,0.75,1.0]
poly_val = ['poly'] 

dizionario_lin_sig_rbf = {}
for g_val in gamma :
    for k_val in kernel:
            for C_val in C :
                for e_val in epsilon :
                    svr_gamma = svm.SVR(gamma=g_val,kernel=k_val, C=C_val, epsilon=e_val)
                    svr_gamma.fit(X_G_SCALED_Tr,Y_G_Tr)
                    Y_pred_Te = svr_gamma.predict(X_G_SCALED_Te)
                    mse = mean_squared_error(Y_G_Te, Y_pred_Te)
                    r2 = r2_score(Y_G_Te,Y_pred_Te)
                    dizionario_lin_sig_rbf[g_val+"_"+k_val+"_"+str(e_val)+"_"+str(C_val)] = [mse, r2]
# Out:
# CPU times: user 5min 31s, sys: 249 ms, total: 5min 31s
# Wall time: 5min 32s

# %%
# %%time
print(dizionario_lin_sig_rbf)
# Out:
# {'scale_linear_0.1_1': [0.7842931709491601, 0.7307788849724673], 'scale_linear_0.25_1': [0.8377321945382243, 0.7124350895021851], 'scale_linear_0.5_1': [0.9481081806432015, 0.6745467753460344], 'scale_linear_0.75_1': [1.0757881948832373, 0.6307185780931708], 'scale_linear_1.0_1': [1.224015691749283, 0.5798371303614223], 'scale_linear_0.1_50': [0.7842931709491601, 0.7307788849724673], 'scale_linear_0.25_50': [0.8377321945382243, 0.7124350895021851], 'scale_linear_0.5_50': [0.9481081806432015, 0.6745467753460344], 'scale_linear_0.75_50': [1.0757881948832373, 0.6307185780931708], 'scale_linear_1.0_50': [1.224015691749283, 0.5798371303614223], 'scale_linear_0.1_64': [0.7842931709491601, 0.7307788849724673], 'scale_linear_0.25_64': [0.8377321945382243, 0.7124350895021851], 'scale_linear_0.5_64': [0.9481081806432015, 0.6745467753460344], 'scale_linear_0.75_64': [1.0757881948832373, 0.6307185780931708], 'scale_linear_1.0_64': [1.224015691749283, 0.5798371303614223], 'scale_linear_0.1_100': 
# ...

# %%
# %%time
dizionario_poly = {}
for g_val in gamma :
    for p_val in poly_val:
        for d_val in degree:
            for C_val in C :
                for e_val in epsilon :
                    svr_poly = svm.SVR(gamma=g_val,kernel=p_val,degree=d_val, C=C_val, epsilon=e_val)
                    svr_poly.fit(X_G_SCALED_Tr,Y_G_Tr)
                    Y_pred_Te_poly = svr_poly.predict(X_G_SCALED_Te)
                    mse_poly = mean_squared_error(Y_G_Te, Y_pred_Te_poly)
                    r2_poly = r2_score(Y_G_Te,Y_pred_Te_poly)
                    dizionario_poly[g_val+"_"+p_val+"_"+str(d_val)+"_"+str(e_val)+"_"+str(C_val)] = [mse_poly, r2_poly]
# Out:
# CPU times: user 19min 37s, sys: 388 ms, total: 19min 38s
# Wall time: 19min 38s

# %%
# %%time
print(dizionario_poly)
# Out:
# {'scale_poly_2_0.1_1': [2.3894993761981245, 0.1797663039203572], 'scale_poly_2_0.25_1': [2.4055461971203553, 0.17425797721122382], 'scale_poly_2_0.5_1': [2.4375501234011954, 0.16327212008823078], 'scale_poly_2_0.75_1': [2.476198206755287, 0.1500055502905191], 'scale_poly_2_1.0_1': [2.5272294995784432, 0.1324882467310352], 'scale_poly_2_0.1_50': [1.9752070528845023, 0.32197873845533853], 'scale_poly_2_0.25_50': [2.025887019180323, 0.3045820333186531], 'scale_poly_2_0.5_50': [2.117445833881788, 0.2731530127717873], 'scale_poly_2_0.75_50': [2.216285548600978, 0.23922470739906532], 'scale_poly_2_1.0_50': [2.319365535392891, 0.2038408611422412], 'scale_poly_2_0.1_64': [1.9752070528845023, 0.32197873845533853], 'scale_poly_2_0.25_64': [2.025887019180323, 0.3045820333186531], 'scale_poly_2_0.5_64': [2.117445833881788, 0.2731530127717873], 'scale_poly_2_0.75_64': [2.216285548600978, 0.23922470739906532], 'scale_poly_2_1.0_64': [2.319365535392891, 0.2038408611422412], 'scale_poly_2_0.1_100': 
# ...

# %%
print(len(dizionario_lin_sig_rbf))
print(len(dizionario_poly))
# Out:
# 150
# 450

# %%
dizionario_lin_sig_rbf.update(dizionario_poly)
print(len(dizionario_lin_sig_rbf))
# Out:
# 600

# %%
print(dizionario_lin_sig_rbf)
# Out:
# {'scale_linear_0.1_1': [0.7842931709491601, 0.7307788849724673], 'scale_linear_0.25_1': [0.8377321945382243, 0.7124350895021851], 'scale_linear_0.5_1': [0.9481081806432015, 0.6745467753460344], 'scale_linear_0.75_1': [1.0757881948832373, 0.6307185780931708], 'scale_linear_1.0_1': [1.224015691749283, 0.5798371303614223], 'scale_linear_0.1_50': [0.7842931709491601, 0.7307788849724673], 'scale_linear_0.25_50': [0.8377321945382243, 0.7124350895021851], 'scale_linear_0.5_50': [0.9481081806432015, 0.6745467753460344], 'scale_linear_0.75_50': [1.0757881948832373, 0.6307185780931708], 'scale_linear_1.0_50': [1.224015691749283, 0.5798371303614223], 'scale_linear_0.1_64': [0.7842931709491601, 0.7307788849724673], 'scale_linear_0.25_64': [0.8377321945382243, 0.7124350895021851], 'scale_linear_0.5_64': [0.9481081806432015, 0.6745467753460344], 'scale_linear_0.75_64': [1.0757881948832373, 0.6307185780931708], 'scale_linear_1.0_64': [1.224015691749283, 0.5798371303614223], 'scale_linear_0.1_100': 
# ...

# %%
SPERIAMO = list(dizionario_lin_sig_rbf.keys())
mse_r2 = list(dizionario_lin_sig_rbf.values())

# %%
mse_vals = []
r2_vals = []
for idx,v in enumerate (mse_r2):
    mse_vals.append(v[0])
    r2_vals.append(v[1])
    
print("mse:\n", mse_vals)
print("r2_vals:\n", r2_vals)
# Out:
# mse:
# ...

# %%
DATAFRAME_SPLITTATO_G = pd.DataFrame(SPERIAMO, columns=['hyperparameters'])
DATAFRAME_SPLITTATO_G['mse'] = mse_vals
DATAFRAME_SPLITTATO_G['r2'] = r2_vals
DATAFRAME_SPLITTATO_G
# Out:
#             hyperparameters       mse        r2
# 0        scale_linear_0.1_1  0.784293  0.730779
# 1       scale_linear_0.25_1  0.837732  0.712435
# 2        scale_linear_0.5_1  0.948108  0.674547
# 3       scale_linear_0.75_1  1.075788  0.630719
# 4        scale_linear_1.0_1  1.224016  0.579837
# ..                      ...       ...       ...
# 595   auto_poly_10_0.1_1000  2.985433 -0.024797
# 596  auto_poly_10_0.25_1000  2.990996 -0.026707
# 597   auto_poly_10_0.5_1000  3.001319 -0.030251
# 598  auto_poly_10_0.75_1000  3.012325 -0.034029
# 599   auto_poly_10_1.0_1000  3.023595 -0.037897
#
# [600 rows x 3 columns]

# %%
DATAFRAME_ORDINATO_SPERO = DATAFRAME_SPLITTATO_G.sort_values(by=['mse'])
DATAFRAME_ORDINATO_SPERO
# Out:
#              hyperparameters         mse          r2
# 105      auto_sigmoid_0.1_50    0.696389    0.760953
# 115     auto_sigmoid_0.1_100    0.696389    0.760953
# 120    auto_sigmoid_0.1_1000    0.696389    0.760953
# 110      auto_sigmoid_0.1_64    0.696389    0.760953
# 111     auto_sigmoid_0.25_64    0.741415    0.745498
# ..                       ...         ...         ...
# 374   scale_poly_10_1.0_1000    3.109970   -0.067547
# 40     scale_sigmoid_0.1_100    5.089283   -0.746977
# 41    scale_sigmoid_0.25_100    5.261459   -0.806080
# 45    scale_sigmoid_0.1_1000  462.941626 -157.912082
# 46   scale_sigmoid_0.25_1000  464.609974 -158.484769
#
# [600 rows x 3 columns]

# %%
for v in DATAFRAME_ORDINATO_SPERO['hyperparameters'] :
    print(v)
# Out:
# auto_sigmoid_0.1_50
# auto_sigmoid_0.1_100
# auto_sigmoid_0.1_1000
# auto_sigmoid_0.1_64
# auto_sigmoid_0.25_64
# auto_sigmoid_0.25_50
# auto_sigmoid_0.25_1000
# auto_sigmoid_0.25_100
# auto_linear_0.1_50
# auto_linear_0.1_64
# scale_linear_0.1_1000
# scale_linear_0.1_64
# auto_linear_0.1_100
# auto_linear_0.1_1000
# scale_linear_0.1_100
# auto_linear_0.1_1
# scale_linear_0.1_50
# scale_linear_0.1_1
# scale_sigmoid_0.5_64
# scale_sigmoid_0.5_100
# scale_sigmoid_0.5_50
# scale_sigmoid_0.5_1000
# scale_linear_0.25_1000
# auto_linear_0.25_100
# scale_linear_0.25_64
# auto_linear_0.25_64
# auto_linear_0.25_50
# scale_linear_0.25_50
# auto_linear_0.25_1
# scale_linear_0.25_1
# auto_linear_0.25_1000
# scale_linear_0.25_100
# auto_sigmoid_0.5_50
# auto_sigmoid_0.5_64
# auto_sigmoid_0.5_100
# auto_sigmoid_0.5_1000
# auto_rbf_0.1_1000
# auto_rbf_0.1_100
# auto_rbf_0.1_50
# auto_rbf_0.1_64
# scale_rbf_0.1_1000
# scale_rbf_0.1_100
# scale_rbf_0.1_64
# scale_rbf_0.1_50
# auto_rbf_0.25_1000
# ...

# %%
DATAFRAME_ORDINATO_SPERO.to_csv("DATAFRAME_ORDINATO_SPERO_G.csv")
